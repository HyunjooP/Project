# %%
import pandas as pd

df = pd.read_csv('/content/symptom (1).csv')
df.head(50)
# Out:
#     Unnamed: 0      증상    개수
# 0            0      통증  1151
# 1            1     근육통  1149
# 2            2     관절염   921
# 3            3      피로   920
# 4            4     관절통   862
# 5            5     근육통   786
# 6            6     피부염   685
# 7            7     비타민   677
# 8            8     비타민   627
# 9            9     신경통   576
# 10          10      발열   571
# 11          11      발육   571
# 12          12      두통   569
# 13          13      병중   547
# 14          14     신경통   543
# 15          15      저하   543
# 16          16      두통   542
# 17          17      습진   536
# 18          18    육체피로   529
# 19          19     관절통   521
# 20          20      외상   503
# 21          21      관절   495
# 22          22      감기   493
# 23          23      발열   456
# 24          24      습진   450
# 25          25  병중병후병을   418
# 26          26      백선   415
# 27          27      위염   412
# 28          28      소화   391
# 29          29      상처   369
# 30          30      만성   366
# ...

# %%
df = df[['증상']]

# %%
df = df.drop_duplicates()
df.head(10)
# Out:
#      증상
# 0    통증
# 1   근육통
# 2   관절염
# 3    피로
# 4   관절통
# 6   피부염
# 7   비타민
# 9   신경통
# 10   발열
# 11   발육

# %%
df = df.sort_values('증상')
df.head(20)
# Out:
#        증상
# 158    6의
# 45     가래
# 73    가려움
# 51     각기
# 22     감기
# 169   감기로
# 48    감기의
# 35     감염
# 74    감염증
# 125    감퇴
# 96     강직
# 166   강직성
# 97     개선
# 162   개선에
# 116   갱년기
# 170  갱년기시
# 196   거담에
# 144    건염
# 78     건조
# 161  건조감의

# %%
df.shape
# Out:
# (172, 1)

# %%
df.to_csv('증상.csv')

# %%
df = pd.read_csv('/content/total_count.csv')
df.head()
# Out:
#    Unnamed: 0    증상   개수_x    개수_y
# 0           0   근육통  786.0  1149.0
# 1           1   비타민  627.0   677.0
# 2           2   신경통  543.0   576.0
# 3           3    두통  542.0   569.0
# 4           4  육체피로  529.0     NaN
